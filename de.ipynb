# %%
import pandas as pd

# %%
tab = pd.read_excel("teste.xlsx")

# %%
tab
# Out:
#                 Vendedor                          E-mail  \
# 0     Alfreda F. Ellison             nec.quam@icloud.net
# 1             Maile King               pede.ac@yahoo.com
# 2          Mason Guthrie  turpis.nulla.aliquet@icloud.ca
# 3         Lenore Sellers                  vel@icloud.net
# 4        Justin R. Morin          suspendisse@google.net
# ..                   ...                             ...
# 495      Chase Whitehead              vestibulum@aol.net
# 496  Aristotle H. Sawyer             morbi@protonmail.ca
# 497      Quinlan I. Lowe                   massa@aol.net
# 498       Shannon Nieves           ut.nec.urna@yahoo.org
# 499    Maggie V. Nielsen            rutrum@protonmail.ca
#
#                                         Empresa        Cidade Data_Venda  \
# 0                          Orci Sem Corporation  Schellebelle 2022-01-21
# 1                             A Feugiat Limited        CheÅ‚m 2022-01-16
# ...
